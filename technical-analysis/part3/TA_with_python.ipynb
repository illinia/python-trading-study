# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import cufflinks as cf
from pandas_datareader import data
import yfinance as yf

# %%
start = "2010-01-01"
end = "2021-01-01"

# %%
symbol = "MSFT"

# %%
df = pd.DataFrame(yf.download(tickers=[symbol], start=start, end=end))
df

# %%
df.info()

# %%
symbol = ["MSFT", "GE", "AAPL"]

# %%
df = pd.DataFrame(yf.download(tickers=symbol, start=start, end=end))
df

# %%
df.to_csv("stocks.csv")

# %%
df = pd.read_csv("stocks.csv", header=[0, 1], index_col=0, parse_dates=[0])
df

# %%
df.info()

# %%
df.Close.GE

# %%
df.Close.GE.plot(figsize=(12, 8))
plt.show()

# %%
df.loc["2020-06":, ("Close", "GE")].plot(figsize=(12, 8))
plt.show()

# %%
cf.set_config_file(offline=True)

# %%
df.loc["2020-06":, ("Close", "GE")].iplot()

# %%
df.Close.iplot()

# %%
df.Close

# %%
df.Close.iplot(fill=True)

# %%
cf.colors.scales()

# %%
df.Close.iplot(fill=True, colorscale="reds")

# %%
cf.getThemes()

# %%
df.Close.iplot(fill=True, colorscale="rdylbu", theme="solar")

# %%
df.Close.iplot(fill=True, colorscale="rdylbu", theme="solar", title="US Stocks", xTitle="Time", yTitle="Stock Price")

# %%
df.Close[["GE", "AAPL"]].iplot(kind="spread", fill=True, colorscale="rdylbu", theme="solar", title="GE vs AAPL", xTitle="Time", yTitle="Stock Price")

# %%
df.swaplevel(axis=1)

# %%
ge = df.swaplevel(axis=1).GE.copy()
ge

# %%
ge.loc["5-2017"].iplot(kind="candle")

# %%
ge.loc["5-2017"].iplot(kind="ohlc")

# %%
from pandas.tseries.frequencies import to_offset

# %%
weekly = ge.resample("W-Fri").agg({"Open": "first",
                                   "High": "max",
                                   "Low": "min",
                                   "Close": "last"})
weekly

# %%
weekly.index = weekly.index - to_offset("4d")

# %%
weekly

# %%
weekly.loc["5-2017":"9-2017"].iplot(kind="candle")

# %%
ge

# %%
qf = cf.QuantFig(df=ge.loc["5-2017"])

# %%
type(qf)

# %%
qf.iplot(title="GE", name="GE")

# %%
qf.add_volume(colorchange=False)

# %%
qf = cf.QuantFig(df=ge.loc["2017":"2018"])
qf.add_sma(periods=20)

# %%
qf.iplot(title="GE", name="GE")

# %%
qf.add_sma(100)

# %%
qf.add_bollinger_bands()

# %%
qf = cf.QuantFig(df=ge.loc["2017":"2018"])

# %%
qf.add_macd()
qf.add_dmi()

# %%
qf.iplot(title="GE", name="GE")

# %% [markdown]
# ### 상승 추세선

# %%
qf = cf.QuantFig(df=ge.loc["2012"])

# %%
qf.iplot(title="GE", name="GE")

# %%
qf.add_trendline(date0="2012-07-12", date1="2012-09-04")

# %% [markdown]
# ### 하락 추세선

# %%
qf = cf.QuantFig(df=ge.loc["2018"])

# %%
qf.iplot(title="GE", name="GE")

# %%
qf.add_trendline(date0="2018-05-22", date1="2018-10-09")

# %% [markdown]
# ### 지지선과 저항선

# %%
ge

# %%
qf = cf.QuantFig(df=ge.loc["2012"])

# %%
qf.iplot(title="GE", name="GE")
# Out:
# <div>                            <div id="f394eee0-4e21-4052-a87e-10933e5fc382" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f394eee0-4e21-4052-a87e-10933e5fc382")) {                    Plotly.newPlot(                        "f394eee0-4e21-4052-a87e-10933e5fc382",                        [{"close":[110.25040435791016,111.4513931274414,111.39134216308594,111.99183654785156,113.25286865234376,112.41217803955078,113.37296295166016,113.67321014404295,113.1327667236328,112.5322723388672,114.21365356445312,114.99429321289062,114.99429321289062,113.73326110839844,113.1327667236328,114.87419891357422,114.51390075683594,114.2737045288086,113.4930648803711,112.35212707519533,112.7124252319336,112.59232330322266,114.21365356445312,114.39380645751952,115.17444610595705,115.53473663330078,114.87419891357422,113.37296295166016,114.51390075683594,113.73326110839844,112.65237426757812,114.15360260009766,115.77493286132812,116.55557250976562,116.43547821044922,115.95508575439452,115.53473663330078,114.51390075683594,115.0543441772461,114.39380645751952,114.81414794921876,113.91340637207033,113.19281768798828,110.61070251464844,112.7124252319336,114.2737045288086,114.33375549316406,114.87419891357422,117.63645935058594,118.8374481201172,121.05927276611328,121.29946899414062,121.35951232910156,120.5188217163086,120.5188217163086,119.19773864746094,118.77739715576172,120.3987274169922,120.33867645263672,120.15853118896484,119.79823303222656,120.5188217163086,120.21858215332033,119.85828399658205,118.53720092773438,117.03597259521484,115.29454040527344,112.5322723388672,114.15360260009766,115.89503479003906,113.37296295166016,113.4930648803711,116.1352310180664,114.6940460205078,114.93424224853516,116.2553253173828,114.51390075683594,117.33621978759766,116.7957763671875,117.81661224365234,118.77739715576172,117.576416015625,118.89749908447266,118.71734619140624,117.75656127929688,116.1352310180664,116.01512908935548,115.59478759765624,113.55311584472656,114.63400268554688,114.15360260009766,111.69158935546876,110.4906005859375,114.09355926513672,113.37296295166016,113.7933120727539,114.81414794921876,115.17444610595705,115.17444610595705,115.59478759765624,115.29454040527344,116.19528198242188,114.33375549316406,114.63400268554688,111.33129119873048,108.98937225341795,109.52981567382812,113.37296295166016,114.09355926513672,115.29454040527344,114.75409698486328,116.97592163085938,116.31537628173828,118.41709899902344,120.09848022460938,118.59725189208984,120.09848022460938,120.698974609375,117.2761688232422,118.9575424194336,117.21611785888672,118.89749908447266,120.87911987304688,121.29946899414062,125.14261627197266,123.0408935546875,122.68059539794922,122.08010864257812,120.09848022460938,120.33867645263672,117.81661224365234,118.1769027709961,116.73572540283205,118.71734619140624,117.63645935058594,118.41709899902344,119.1376953125,118.89749908447266,119.31784057617188,120.63892364501952,119.9183349609375,120.09848022460938,123.46123504638672,125.62300872802734,124.90242004394533,124.6021728515625,124.4820785522461,123.22103881835938,125.86320495605467,125.92325592041016,126.8239974975586,126.1634521484375,126.46369934082033,126.70389556884766,126.0433578491211,125.74311065673828,125.86320495605467,126.40364837646484,126.10340881347656,125.6830596923828,125.20266723632812,124.7823257446289,123.94163513183594,124.90242004394533,125.20266723632812,124.96247100830078,125.02251434326172,123.94163513183594,124.36197662353516,123.16099548339844,124.00167846679688,127.96492767333984,129.6463165283203,128.9857635498047,129.6463165283203,131.44778442382812,132.22842407226562,132.7688751220703,132.4085693359375,133.5495147705078,134.69044494628906,134.69044494628906,135.2909393310547,134.2700958251953,133.9698486328125,132.7088165283203,136.49192810058594,136.371826171875,136.97232055664062,136.8522186279297,137.57281494140625,137.81300354003906,138.83384704589844,137.6328582763672,135.8313751220703,134.69044494628906,135.17083740234375,134.990692138 ...

# %%
qf.add_resistance(date="2012-03-28")

# %% [markdown]
# ### 지지선

# %%
qf = cf.QuantFig(df=ge.loc["2013"])

# %%
qf.iplot(title="GE", name="GE")
# Out:
# <div>                            <div id="0153bc96-ff7d-43fa-9500-637d448de2d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("0153bc96-ff7d-43fa-9500-637d448de2d5")) {                    Plotly.newPlot(                        "0153bc96-ff7d-43fa-9500-637d448de2d5",                        [{"close":[128.14508056640625,126.70389556884766,127.30438995361328,126.88404846191406,125.50291442871094,125.80316162109376,127.1242446899414,126.88404846191406,126.8239974975586,127.30438995361328,126.8239974975586,127.9048843383789,132.34852600097656,132.1683807373047,131.74803161621094,132.4085693359375,133.84976196289062,135.1107940673828,135.1107940673828,133.4894561767578,133.78970336914062,135.8313751220703,133.9698486328125,135.35098266601562,134.75048828125,134.99069213867188,135.1107940673828,134.810546875,135.5911865234375,140.45516967773438,140.5752716064453,139.85467529296875,142.616943359375,140.5752716064453,139.67453002929688,140.45516967773438,136.97232055664062,138.4134979248047,140.33506774902344,139.43434143066406,139.25418090820312,139.73458862304688,141.65615844726562,142.1365509033203,142.19659423828125,142.73704528808594,141.8363037109375,140.5752716064453,141.0556640625,142.25665283203125,140.7554168701172,139.61448669433594,140.0348358154297,140.87551879882812,139.85467529296875,140.33506774902344,139.55442810058594,138.83384704589844,138.7137451171875,138.83384704589844,138.59364318847656,140.15492248535156,138.11325073242188,138.59364318847656,137.69290161132812,138.83384704589844,138.47354125976562,141.5961151123047,141.65615844726562,140.87551879882812,136.97232055664062,138.7137451171875,136.6720733642578,136.13162231445312,130.6071014404297,128.2051239013672,129.10586547851562,131.86813354492188,131.80809020996094,133.36936950683594,133.7296600341797,133.84976196289062,133.00906372070312,134.0299072265625,135.53114318847656,135.5911865234375,136.19168090820312,138.17330932617188,136.79217529296875,137.51275634765625,137.21250915527344,138.17330932617188,139.55442810058594,139.73458862304688,140.87551879882812,141.5360565185547,142.07650756835938,143.27748107910156,142.07650756835938,141.29586791992188,141.71620178222656,141.95640563964844,141.71620178222656,140.0348358154297,141.95640563964844,142.07650756835938,140.0348358154297,140.39512634277344,143.27748107910156,142.79708862304688,141.5961151123047,141.11570739746094,142.19659423828125,141.23580932617188,142.73704528808594,146.0998077392578,143.99807739257812,139.61448669433594,140.2750244140625,137.69290161132812,138.77378845214844,139.61448669433594,140.0348358154297,139.25418090820312,140.15492248535156,137.51275634765625,137.57281494140625,139.55442810058594,140.0348358154297,141.8363037109375,141.3559112548828,143.75787353515625,142.677001953125,141.8963623046875,140.69537353515625,141.3559112548828,141.8963623046875,148.4417266845703,149.28240966796875,148.3816680908203,147.8412322998047,148.26158142089844,148.02137756347656,147.0605926513672,147.0005340576172,146.33999633789062,147.8412322998047,148.32162475585938,147.24073791503906,145.97970581054688,146.15985107421875,146.0998077392578,145.61941528320312,145.739501953125,145.3191680908203,144.5385284423828,144.11817932128906,143.81793212890625,143.21743774414062,142.43679809570312,141.77626037597656,142.79708862304688,142.79708862304688,141.77626037597656,139.1941375732422,139.31423950195312,138.77378845214844,138.95394897460938,138.47354125976562,139.13409423828125,139.07403564453125,139.07403564453125,140.45516967773438,143.33753967285156,144.6586151123047,143.21743774414062,142.79708862304688,144.9588623046875,146.8203887939453,149.28240966796875,146.8804473876953,144.17822265625,145.799560546875,146.0397491455078,145.4993133544922,145.61941528320312,144.41842651367188,143.4576416015625,145.13900756835938,146.0998077392578,144.7186737060547,144.41842651367188,143.75787353515625,142.1365509033203,141.5360565185547,145.61941528320312,146.5201416015625,146.40005493164062,145.2591094970703,146.2 ...

# %%
qf.add_support(date="2013-06-24")
