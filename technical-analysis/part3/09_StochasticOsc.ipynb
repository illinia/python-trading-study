# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
pd.read_csv("EURUSD_ohlc.csv")
# Out:
#       Unnamed: 0     Open     High      Low    Close
# 0     2008-01-01  1.45905  1.47502  1.45885  1.47146
# 1     2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2     2008-01-03  1.47504  1.48254  1.46958  1.47429
# 3     2008-01-05  1.47451  1.47559  1.47430  1.47465
# 4     2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...          ...      ...      ...      ...      ...
# 3806  2020-12-23  1.21873  1.22158  1.21774  1.21849
# 3807  2020-12-27  1.21892  1.22504  1.21812  1.22152
# 3808  2020-12-28  1.22145  1.22752  1.22086  1.22502
# 3809  2020-12-29  1.22508  1.23102  1.22495  1.23000
# 3810  2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 5 columns]

# %%
data = pd.read_csv("EURUSD_ohlc.csv", parse_dates=[0], index_col=0)
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2008-01-01 to 2020-12-30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3811 non-null   float64
#  1   High    3811 non-null   float64
#  2   Low     3811 non-null   float64
#  3   Close   3811 non-null   float64
# dtypes: float64(4)
# memory usage: 148.9 KB

# %%
data.Close.plot(figsize=(12, 8), title="EUR/USD", fontsize=12)
plt.show()

# %% [markdown]
# **스톡캐스틱 오실리레이터 지표**는 0 에서 100 까지 움직이는 다른 선/오실리레이터를 두 개 포함한다.
#
# * 빠른 스톡캐스틱 지표(%K line)
# * 느린 스톡캐스틱 지표(%D line)
#
# %K 를 계산하는 법
#
# %K = (C - L14) / (H14 - L14) * 100
# * C = 가장 최근 종료 가격
# * L14 = 지난 14일 동안 최저 가격
# * H14 = 지난 14일 동안 최고 가격

# %%
periods = 14

# %%
data["roll_low"] = data.Low.rolling(periods).min()
data["roll_high"] = data.High.rolling(periods).max()
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high
# 2008-01-01  1.45905  1.47502  1.45885  1.47146       NaN        NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510       NaN        NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429       NaN        NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465       NaN        NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954       NaN        NaN
# ...             ...      ...      ...      ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102
#
# [3811 rows x 6 columns]

# %%
data.loc[:, ["Close", 'roll_low', 'roll_high']].plot(figsize=(12, 8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
data.loc["2016", ["Close", 'roll_low', 'roll_high']].plot(figsize=(12, 8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
data["K"] = (data.Close - data.roll_low) / (data.roll_high - data.roll_low) * 100
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high          K
# 2008-01-01  1.45905  1.47502  1.45885  1.47146       NaN        NaN        NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510       NaN        NaN        NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429       NaN        NaN        NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465       NaN        NaN        NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954       NaN        NaN        NaN
# ...             ...      ...      ...      ...       ...        ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728  58.925234
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728  73.084112
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752  88.447320
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102  95.655877
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102  53.808594
#
# [3811 rows x 7 columns]

# %%
data.loc["2016", ["Close", 'roll_low', 'roll_high', 'K']].plot(figsize=(12, 8), fontsize=12, secondary_y="K")
plt.legend(fontsize=12)
plt.show()

# %%
moving_av = 3

# %%
data["D"] = data.K.rolling(moving_av).mean()

# %%
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146       NaN        NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510       NaN        NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429       NaN        NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465       NaN        NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954       NaN        NaN
# ...             ...      ...      ...      ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102
#
#                     K          D
# 2008-01-01        NaN        NaN
# 2008-01-02        NaN        NaN
# 2008-01-03        NaN        NaN
# 2008-01-05        NaN        NaN
# 2008-01-06        NaN        NaN
# ...               ...        ...
# 2020-12-23  58.925234  55.623053
# 2020-12-27  73.084112  63.753894
# 2020-12-28  88.447320  73.485555
# 2020-12-29  95.655877  85.729103
# 2020-12-30  53.808594  79.303930
#
# [3811 rows x 8 columns]

# %%
data.loc["2016", ["D", "K"]].plot(figsize=(12, 8), fontsize=12)
plt.show()

# %%
data['position'] = np.where(data['K'] > data['D'], 1, -1)
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146       NaN        NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510       NaN        NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429       NaN        NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465       NaN        NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954       NaN        NaN
# ...             ...      ...      ...      ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102
#
#                     K          D  position
# 2008-01-01        NaN        NaN        -1
# 2008-01-02        NaN        NaN        -1
# 2008-01-03        NaN        NaN        -1
# 2008-01-05        NaN        NaN        -1
# 2008-01-06        NaN        NaN        -1
# ...               ...        ...       ...
# 2020-12-23  58.925234  55.623053         1
# 2020-12-27  73.084112  63.753894         1
# 2020-12-28  88.447320  73.485555         1
# 2020-12-29  95.655877  85.729103         1
# 2020-12-30  53.808594  79.303930        -1
#
# [3811 rows x 9 columns]

# %%
data.loc["04-2016", ["K", 'D', 'position']].plot(figsize=(12, 8), fontsize=12, secondary_y='position')
plt.show()

# %% [markdown]
# ### 벡터화 백테스팅

# %%
data['returns'] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data.dropna(inplace=True)

# %%
data['strategy'] = data.position.shift(1) * data['returns']

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high  \
# 2008-01-20  1.46040  1.46046  1.44218  1.44544   1.44218    1.49224
# 2008-01-21  1.44538  1.46434  1.43664  1.46294   1.43664    1.49224
# 2008-01-22  1.46292  1.46844  1.45114  1.46304   1.43664    1.49224
# 2008-01-23  1.46298  1.47794  1.45912  1.47556   1.43664    1.49224
# 2008-01-24  1.47546  1.47778  1.46610  1.46813   1.43664    1.49224
# ...             ...      ...      ...      ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102
#
#                     K          D  position   returns  strategy
# 2008-01-20   6.512185   6.728020        -1 -0.010262  0.010262
# 2008-01-21  47.302158  19.330342         1  0.012034 -0.012034
# 2008-01-22  47.482014  33.765453         1  0.000068  0.000068
# 2008-01-23  70.000000  54.928058         1  0.008521  0.008521
# 2008-01-24  56.636691  58.039568        -1 -0.005048 -0.005048
# ...               ...        ...       ...       ...       ...
# 2020-12-23  58.925234  55.623053         1 -0.000057  0.000057
# 2020-12-27  73.084112  63.753894         1  0.002484  0.002484
# 2020-12-28  88.447320  73.485555         1  0.002861  0.002861
# 2020-12-29  95.655877  85.729103         1  0.004057  0.004057
# 2020-12-30  53.808594  79.303930        -1 -0.006885 -0.006885
#
# [3795 rows x 11 columns]

# %%
ptc = 0.00007

# %%
data['trades'] = data.position.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 0.0    2287
# 2.0    1508
# Name: trades, dtype: int64

# %%
data['strategy_net'] = data.strategy - data.trades * ptc

# %%
data['creturns'] = data['returns'].cumsum().apply(np.exp)
data['cstrategy'] = data['strategy'].cumsum().apply(np.exp)
data['cstrategy_net'] = data['strategy_net'].cumsum().apply(np.exp)

# %%
data
# Out:
#                Open     High      Low    Close  roll_low  roll_high  \
# 2008-01-20  1.46040  1.46046  1.44218  1.44544   1.44218    1.49224
# 2008-01-21  1.44538  1.46434  1.43664  1.46294   1.43664    1.49224
# 2008-01-22  1.46292  1.46844  1.45114  1.46304   1.43664    1.49224
# 2008-01-23  1.46298  1.47794  1.45912  1.47556   1.43664    1.49224
# 2008-01-24  1.47546  1.47778  1.46610  1.46813   1.43664    1.49224
# ...             ...      ...      ...      ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156   1.21054    1.23102
#
#                     K          D  position   returns  strategy  trades  \
# 2008-01-20   6.512185   6.728020        -1 -0.010262  0.010262     0.0
# 2008-01-21  47.302158  19.330342         1  0.012034 -0.012034     2.0
# 2008-01-22  47.482014  33.765453         1  0.000068  0.000068     0.0
# 2008-01-23  70.000000  54.928058         1  0.008521  0.008521     0.0
# 2008-01-24  56.636691  58.039568        -1 -0.005048 -0.005048     2.0
# ...               ...        ...       ...       ...       ...     ...
# 2020-12-23  58.925234  55.623053         1 -0.000057  0.000057     2.0
# 2020-12-27  73.084112  63.753894         1  0.002484  0.002484     0.0
# 2020-12-28  88.447320  73.485555         1  0.002861  0.002861     0.0
# 2020-12-29  95.655877  85.729103         1  0.004057  0.004057     0.0
# 2020-12-30  53.808594  79.303930        -1 -0.006885 -0.006885     2.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-20      0.010262  0.989790   1.010315       1.010315
# 2008-01-21     -0.012174  1.001774   0.998230       0.998090
# 2008-01-22      0.000068  1.001842   0.998298       0.998158
# 2008-01-23      0.008521  1.010415   1.006841       1.006700
# 2008-01-24     -0.005188  1.005327   1.001771       1.001491
# ...                  ...       ...        ...            ...
# 2020-12-23     -0.000083  0.834382   1.349162       1.092538
# 2020-12-27      0.002484  0.836457   1.352517       1.095255
# 2020-12-28      0.002861  0.838854   1.356392       1.098393
# 2020-12-29      0.004057  0.842264   1.361906       1.102859
# 2020-12-30     -0.007025  0.836484   1.352561       1.095138
#
# [3795 rows x 16 columns]

# %%
data[['creturns', 'cstrategy', 'cstrategy_net']].plot(figsize=(12, 8))
plt.show()

# %%
data.loc['2020', ['creturns', 'cstrategy', 'cstrategy_net']].plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ### 스톡캐스팅 백테스터 클래스

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn-v0_8")

# %%
from SOBacktester import SOBacktester as SO

# %%
pd.read_csv("EURUSD_ohlc.csv", parse_dates=[0], index_col=0)
pd.read_csv("US30_ohlc.csv", parse_dates=[0], index_col=0)
pd.read_csv("XAUUSD_ohlc.csv", parse_dates=[0], index_col=0)
# Out:
#                 Open      High       Low     Close
# 2008-01-01   833.900   861.460   833.900   857.310
# 2008-01-02   857.350   868.980   853.590   865.010
# 2008-01-03   865.030   868.840   854.610   859.700
# 2008-01-05   859.070   859.270   858.670   858.970
# 2008-01-06   858.670   865.060   855.330   858.190
# ...              ...       ...       ...       ...
# 2020-12-23  1873.306  1883.725  1869.554  1879.544
# 2020-12-27  1885.053  1900.296  1869.312  1873.694
# 2020-12-28  1873.445  1886.454  1871.848  1878.358
# 2020-12-29  1878.170  1894.598  1876.221  1894.508
# 2020-12-30  1894.284  1901.006  1885.528  1898.422
#
# [3688 rows x 4 columns]

# %% [markdown]
# EURUSD 백테스트

# %%
ptc = 0.00007

# %%
tester = SO("EURUSD", 14, 3, "2008-01-01", "2020-12-31", ptc)

# %%
tester
# Out:
# SOBacktester(symbol = EURUSD, periods = 14, D_mw = 3, start = 2008-01-01, end = 2020-12-31)

# %%
tester.data
# Out:
#                Open     High      Low    Close   returns  roll_low  roll_high  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146       NaN       NaN        NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  0.002471       NaN        NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429 -0.000549       NaN        NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  0.000244       NaN        NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954 -0.003471       NaN        NaN
# ...             ...      ...      ...      ...       ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849 -0.000057   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  0.002484   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  0.002861   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  0.004057   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156 -0.006885   1.21054    1.23102
#
#                     K          D
# 2008-01-01        NaN        NaN
# 2008-01-02        NaN        NaN
# 2008-01-03        NaN        NaN
# 2008-01-05        NaN        NaN
# 2008-01-06        NaN        NaN
# ...               ...        ...
# 2020-12-23  58.925234  55.623053
# 2020-12-27  73.084112  63.753894
# 2020-12-28  88.447320  73.485555
# 2020-12-29  95.655877  85.729103
# 2020-12-30  53.808594  79.303930
#
# [3811 rows x 9 columns]

# %%
tester.test_strategy()
# Out:
# (1.095138, 0.258653)

# %%
tester.results
# Out:
#                Open     High      Low    Close   returns  roll_low  roll_high  \
# 2008-01-20  1.46040  1.46046  1.44218  1.44544 -0.010262   1.44218    1.49224
# 2008-01-21  1.44538  1.46434  1.43664  1.46294  0.012034   1.43664    1.49224
# 2008-01-22  1.46292  1.46844  1.45114  1.46304  0.000068   1.43664    1.49224
# 2008-01-23  1.46298  1.47794  1.45912  1.47556  0.008521   1.43664    1.49224
# 2008-01-24  1.47546  1.47778  1.46610  1.46813 -0.005048   1.43664    1.49224
# ...             ...      ...      ...      ...       ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849 -0.000057   1.20588    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  0.002484   1.20588    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  0.002861   1.20588    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  0.004057   1.20754    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156 -0.006885   1.21054    1.23102
#
#                     K          D  position  strategy  trades  creturns  \
# 2008-01-20   6.512185   6.728020        -1  0.010262     0.0  0.989790
# 2008-01-21  47.302158  19.330342         1 -0.012174     2.0  1.001774
# 2008-01-22  47.482014  33.765453         1  0.000068     0.0  1.001842
# 2008-01-23  70.000000  54.928058         1  0.008521     0.0  1.010415
# 2008-01-24  56.636691  58.039568        -1 -0.005188     2.0  1.005327
# ...               ...        ...       ...       ...     ...       ...
# 2020-12-23  58.925234  55.623053         1 -0.000083     2.0  0.834382
# 2020-12-27  73.084112  63.753894         1  0.002484     0.0  0.836457
# 2020-12-28  88.447320  73.485555         1  0.002861     0.0  0.838854
# 2020-12-29  95.655877  85.729103         1  0.004057     0.0  0.842264
# 2020-12-30  53.808594  79.303930        -1 -0.007025     2.0  0.836484
#
#             cstrategy
# 2008-01-20   1.010315
# 2008-01-21   0.998090
# 2008-01-22   0.998158
# 2008-01-23   1.006700
# 2008-01-24   1.001491
# ...               ...
# 2020-12-23   1.092538
# 2020-12-27   1.095255
# 2020-12-28   1.098393
# 2020-12-29   1.102859
# 2020-12-30   1.095138
#
# [3795 rows x 14 columns]

# %%
tester.plot_results()

# %%
tester.results.trades.value_counts()
# Out:
# 0.0    2287
# 2.0    1508
# Name: trades, dtype: int64

# %%
tester.optimize_parameters((10, 100, 1), (3, 50, 1))
# Out:
# (array([27., 11.]), 1.584622)

# %%
tester.plot_results()

# %%
tester.results.trades.value_counts()
# Out:
# 0.0    3055
# 2.0     719
# Name: trades, dtype: int64

# %% [markdown]
# XAU/USD

# %%
ptc = 0.00015

# %%
tester = SO('XAUUSD', 14, 3, '2008-01-01', '2020-12-31', ptc)

# %%
tester.test_strategy()
# Out:
# (2.441005, 0.31354)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((10, 100, 1), (3, 50, 1))
# Out:
# (array([14., 10.]), 4.64632)

# %%
tester.plot_results()

# %% [markdown]
# 다우지수

# %%
ptc = 0.00007

# %%
tester = SO("US30", 14, 3, "2008-01-01", "2020-12-31", ptc)

# %%
tester.data
# Out:
#                Open     High      Low    Close   returns  roll_low  roll_high  \
# 2008-01-01  13262.9  13303.1  12981.1  13070.7       NaN       NaN        NaN
# 2008-01-02  13070.8  13125.1  13009.9  13074.6  0.000298       NaN        NaN
# 2008-01-03  13074.7  13112.9  12776.0  12817.8 -0.019837       NaN        NaN
# 2008-01-06  12823.6  12891.7  12718.6  12803.5 -0.001116       NaN        NaN
# 2008-01-07  12806.5  12894.6  12553.5  12574.5 -0.018048       NaN        NaN
# ...             ...      ...      ...      ...       ...       ...        ...
# 2020-12-23  30202.5  30273.0  30123.6  30225.2  0.000659   29420.3    30424.7
# 2020-12-27  30131.5  30544.6  30121.5  30442.7  0.007170   29420.3    30544.6
# 2020-12-28  30451.0  30633.0  30300.0  30406.8 -0.001180   29420.3    30633.0
# 2020-12-29  30414.3  30551.4  30344.8  30461.7  0.001804   29420.3    30633.0
# 2020-12-30  30457.2  30661.4  30366.8  30622.2  0.005255   29420.3    30661.4
#
#                     K          D
# 2008-01-01        NaN        NaN
# 2008-01-02        NaN        NaN
# 2008-01-03        NaN        NaN
# 2008-01-06        NaN        NaN
# 2008-01-07        NaN        NaN
# ...               ...        ...
# 2020-12-23  80.137395  72.743263
# 2020-12-27  90.936583  83.076697
# 2020-12-28  81.347407  84.140462
# 2020-12-29  85.874495  86.052828
# 2020-12-30  96.841512  88.021138
#
# [3411 rows x 9 columns]

# %%
tester.test_strategy()
# Out:
# (0.364894, -2.137021)

# %%
tester.optimize_parameters((10, 100, 1), (3, 50, 1))
# Out:
# (array([32., 49.]), 2.509286)

# %%
tester.plot_results()

# %% [markdown]
# 대안 전략과 해석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn-v0_8")
from SOBacktester import SOBacktester as SO

# %%
tester = SO("EURUSD", 27, 11, "2008-01-01", "2020-12-31", 0)

# %%
alt = tester.data.dropna()
alt
# Out:
#                Open     High      Low    Close   returns  roll_low  roll_high  \
# 2008-02-12  1.45844  1.45996  1.45318  1.45734 -0.000755   1.43664    1.49534
# 2008-02-13  1.45734  1.46470  1.45484  1.46428  0.004751   1.43664    1.49534
# 2008-02-14  1.46424  1.47098  1.46312  1.46820  0.002674   1.43664    1.49534
# 2008-02-16  1.46777  1.46825  1.46716  1.46799 -0.000143   1.43664    1.49534
# 2008-02-17  1.46800  1.46905  1.46112  1.46582 -0.001479   1.43664    1.49534
# ...             ...      ...      ...      ...       ...       ...        ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849 -0.000057   1.18002    1.22728
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  0.002484   1.18002    1.22728
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  0.002861   1.18002    1.22752
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  0.004057   1.18002    1.23102
# 2020-12-30  1.22979  1.23094  1.22094  1.22156 -0.006885   1.18369    1.23102
#
#                     K          D
# 2008-02-12  35.264055  44.475763
# 2008-02-13  47.086882  42.002478
# 2008-02-14  53.764906  40.082081
# 2008-02-16  53.407155  37.769862
# 2008-02-17  49.710392  37.930928
# ...               ...        ...
# 2020-12-23  81.400762  90.286576
# 2020-12-27  87.812103  89.743209
# 2020-12-28  94.736842  90.537000
# 2020-12-29  98.000000  91.083465
# 2020-12-30  80.012677  89.780022
#
# [3775 rows x 9 columns]

# %% [markdown]
# 대안 전략1: 50레벨 교차

# %%
alt2 = alt.loc["2016"].copy()

# %%
alt2.loc[:, "K"].plot(figsize=(12, 8))
plt.hlines(y=50, xmin=alt2.index[0], xmax=alt2.index[-1], color="r", label="50-Level")
plt.title("50-Level Crossover", fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# 대안2: 과매수(80) & 과매도(20)
#
# * 과매수시 숏
# * 과매도시 롱

# %%
alt2.loc[:, ["K"]].plot(figsize=(12, 8))
plt.hlines(y=80, xmin=alt2.index[0], xmax=alt2.index[-1], label="Upper", color="r")
plt.hlines(y=20, xmin=alt2.index[0], xmax=alt2.index[-1], label="Lower", color="g")
plt.yticks(ticks=range(0, 100, 10))
plt.legend()
plt.show()
